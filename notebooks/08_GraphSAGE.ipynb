# %% [markdown]
# # Enterprise AI Fraud Detection Platform
# **Notebook:** 08_GraphSAGE
# **Author:** Somsubhra Dalui
# **Version:** v1.0
# **Date:**
#
# **Purpose:** Train and evaluate a reproducible GraphSAGE model on the transaction graph.

# %%
from src.utils.bootstrap import bootstrap
bootstrap()

import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
