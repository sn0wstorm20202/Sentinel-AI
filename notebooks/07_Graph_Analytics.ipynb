# %% [markdown]
# # Enterprise AI Fraud Detection Platform
# **Notebook:** 07_Graph_Analytics
# **Author:** Somsubhra Dalui
# **Version:** v1.0
# **Date:**
#
# **Purpose:** Construct the transaction graph and evaluate graph-derived fraud signals.

# %%
from src.utils.bootstrap import bootstrap
bootstrap()

import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
