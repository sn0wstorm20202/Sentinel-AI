# %% [markdown]
# # Enterprise AI Fraud Detection Platform
# **Notebook:** 10_Final_Pipeline
# **Author:** Somsubhra Dalui
# **Version:** v1.0
# **Date:**
#
# **Purpose:** Execute and validate the final end-to-end reproducible fraud-detection pipeline.

# %%
from src.utils.bootstrap import bootstrap
bootstrap()

import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
