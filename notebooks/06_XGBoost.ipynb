# %% [markdown]
# # Enterprise AI Fraud Detection Platform
# **Notebook:** 06_XGBoost
# **Author:** Somsubhra Dalui
# **Version:** v1.0
# **Date:**
#
# **Purpose:** Train, tune, and evaluate an XGBoost fraud classifier using the fixed evaluation protocol.

# %%
from src.utils.bootstrap import bootstrap
bootstrap()

import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
