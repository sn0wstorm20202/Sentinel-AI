# %% [markdown]
# # Enterprise AI Fraud Detection Platform
# **Notebook:** 05_Baseline_Models
# **Author:** Somsubhra Dalui
# **Version:** v1.0
# **Date:**
#
# **Purpose:** Establish leakage-safe baseline models and evaluation metrics for comparison.

# %%
from src.utils.bootstrap import bootstrap
bootstrap()

import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
