# %% [markdown]
# # Enterprise AI Fraud Detection Platform
# **Notebook:** 09_SHAP
# **Author:** Somsubhra Dalui
# **Version:** v1.0
# **Date:**
#
# **Purpose:** Produce global and local SHAP explanations for the selected model.

# %%
from src.utils.bootstrap import bootstrap
bootstrap()

import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
